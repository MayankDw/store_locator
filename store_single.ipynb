# %% [markdown]
# <a href="https://colab.research.google.com/github/MayankDw/store_locator/blob/main/store_single.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4) (4.13.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4) (4.12.2)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup
import requests
addr = []
url = "https://stores.footlocker.com/mi/annarbor/"
# get html content from url
html_content = requests.get(url).text
# parse the content
soup = BeautifulSoup(html_content, 'lxml')
#print(soup.prettify()) #print the parsed data
#soup.prettify()
table = [soup.find("div", attrs = {'class':'address'}).get_text()]

for x in table:
    addr.append(x.strip().replace('\n', ''))

print(addr)
# Out:
# ['672 Briarwood Circle Ann Arbor, MI 48108']

# %%
from bs4 import BeautifulSoup
import requests
addr = []
urls = [ "https://stores.footlocker.com/mi/annarbor"
,"https://stores.footlocker.com/mi/auburnhills"
,"https://stores.footlocker.com/mi/dearborn"
,"https://stores.footlocker.com/mi/detroit"
,"https://stores.footlocker.com/mi/eastpointe"
,"https://stores.footlocker.com/mi/flint"
,"https://stores.footlocker.com/mi/grandrapids"
,"https://stores.footlocker.com/mi/grandville"
,"https://stores.footlocker.com/mi/harperwoods"
,"https://stores.footlocker.com/mi/highlandpark"
,"https://stores.footlocker.com/mi/lansing"
,"https://stores.footlocker.com/mi/muskegon"
,"https://stores.footlocker.com/mi/novi"
,"https://stores.footlocker.com/mi/oakpark"
,"https://stores.footlocker.com/mi/okemos"
,"https://stores.footlocker.com/mi/portage"
,"https://stores.footlocker.com/mi/redford"
,"https://stores.footlocker.com/mi/roseville"
,"https://stores.footlocker.com/mi/shelbytownship"
,"https://stores.footlocker.com/mi/southfield"
,"https://stores.footlocker.com/mi/taylor"
,"https://stores.footlocker.com/mi/troy"
,"https://stores.footlocker.com/mi/westland"
       ]
# get html content from url
for url in urls:
    html_content = requests.get(url).text
    # parse the content
    soup = BeautifulSoup(html_content, 'lxml')
    #print(soup.prettify()) #print the parsed data
    #soup.prettify()
    if soup.find("div", attrs = {'class':'address'}) is not None:
         table = [soup.find("div", attrs = {'class':'address'}).get_text()]

    for x in table:
        addr.append(x.strip().replace('\n', ''))

print(addr)
# Out:
# ['672 Briarwood Circle Ann Arbor, MI 48108', '4186 Baldwin Road Suite 336Auburn Hills, MI 48326', '18900 Michigan Avenue Space M-124Dearborn, MI 48126', '14296 Gratiot Avenue Detroit, MI 48205', '15015 East 8 Mile Road Eastpointe, MI 48021', '15015 East 8 Mile Road Eastpointe, MI 48021', '3115 28th Street Southeast Space F-104Grand Rapids, MI 49512', '3700 Rivertown Parkway Space 1204Grandville, MI 49418', '17755 East Eight Mile Road Harper Woods, MI 48225', '14108 Woodward Avenue Highland Park, MI 48203', '5356 West Saginaw Highway Lansing, MI 48917', '5356 West Saginaw Highway Lansing, MI 48917', '27694 Novi Road Novi, MI 48377', '21230 Greenfield Rd Oak Park, MI 48237', '1982 West Grand River Avenue Space 553Okemos, MI 48864', '6650 South Westnedge Avenue Space 142Portage, MI 49024', '9189 Telegraph Road Redford, MI 48239', '32401 Gratiot Avenue Roseville, MI 48066', '13825 Hall Road Shelby Township, MI 48315', '28670 Telegraph Road Southfield, MI 48034', '23000 Eureka Road Space 1690Taylor, MI 48180', '362 West 14 Mile Road Troy, MI 48083', '35000 West Warren Road Westland, MI 48185']

# %%
import geopy
import folium
addr = ['672 Briarwood Circle Ann Arbor, MI 48108', '4186 Baldwin Rd Auburn Hills, MI 48326', '18900 Michigan Ave Dearborn, MI 48126',
        '1351 West 8 Mile Rd Detroit, MI 48203', '15015 East 8 Mile Rd Eastpointe, MI 48021', '3445 S Linden Rd, Flint, MI 48507',
        '3115 28th St Southeast Grand Rapids, MI 49512', '3700 Rivertown Parkway Grandville, MI 49418', '17755 East 8 Mile Rd Harper Woods, MI 48225',
        '14108 Woodward Ave Highland Park, MI 48203', '5356 West Saginaw Highway Lansing, MI 48917', '5600 Harvey St Muskegon, MI 49444',
        '27694 Novi Rd Novi, MI 48377', '21230 Greenfield Rd Oak Park, MI 48237', '1982 W Grand River Ave Okemos, MI 48864',
        '6650 South Westnedge Ave Portage, MI 49024', '9189 Telegraph Rd, Redford, MI 48239', '32401 Gratiot Ave Roseville, MI 48066',
        '13825 Hall Rd Shelby Township, MI 48315', '28670 Telegraph Rd, Southfield, MI 48034', '23000 Eureka Rd Taylor, MI 48180',
        '362 W 14 Mile Rd Troy, MI 48083', '35000 Warren Rd Westland, MI 48185']

object = geopy.Nominatim(user_agent = 'store_single')

def get_geodata(address):
    try:
        return object.geocode(address)
    except:
        return None

incorrect_addr = []
cent_loc = 'Lansing, MI'
center = get_geodata(cent_loc)
if center is not None:
    map1 = folium.Map(location= [center.latitude, center.longitude], zoom_start=7)
else:
    print('The Map location is incorrect, cannot draw map')

for location in addr:
    geodata = get_geodata(location)
    if geodata is not None:
        folium.Marker([geodata.latitude, geodata.longitude], draggble=True).add_to(map1)
    else:
        incorrect_addr.append(location)
if len(incorrect_addr) != 0:
    print('These addresses are incorrect:', incorrect_addr)
map1
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4186+Baldwin+Rd+Auburn+Hills%2C+MI+48326&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=18900+Michigan+Ave+Dearborn%2C+MI+48126&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=1351+West+8+Mile+Rd+Detroit%2C+MI+48203&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3445+S+Linden+Rd%2C+Flint%2C+MI+48507&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=17755+East+8+Mile+Rd+Harper+Woods%2C+MI+48225&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=14108+Woodward+Ave+Highland+Park%2C+MI+48203&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5600+Harvey+St+Muskegon%2C+MI+49444&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5600+Harvey+St+Muskegon%2C+MI+49444&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=9189+Telegraph+Rd%2C+Redford%2C+MI+48239&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=13825+Hall+Rd+Shelby+Township%2C+MI+48315&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=28670+Telegraph+Rd%2C+Southfield%2C+MI+48034&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=23000+Eureka+Rd+Taylor%2C+MI+48180&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=35000+Warren+Rd+Westland%2C+MI+48185&format=json&limit=1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e64b582cac7e2b94cb1f87a58e5dfa62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e64b582cac7e2b94cb1f87a58e5dfa62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e64b582cac7e2b94cb1f87a58e5dfa62 = L.map(
#                 &quot;map_e64b582cac7e2b94cb1f87a58e5dfa62&quot;,
#                 {
#                     center: [42.7338254, -84.5546295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5847b73bcf26c0798f224c3c48dc0aee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5847b73bcf26c0798f224c3c48dc0aee.addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_2cd5a36f631213e725048adc262b94f0 = L.marker(
#                 [42.241050200000004, -83.74667569600683],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_360e4331886daf01a76741a8304d685d = L.marker(
#                 [42.690368725344726, -83.30537551397458],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_a9d17a2d02ceb4e5472f96e8c241efbd = L.marker(
#                 [42.31688655, -83.22296100140477],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_27132a9948dbcb1b52f5710ecb9d4b05 = L.marker(
#                 [42.44519452516463, -83.18129761363781],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_29e8da8d6af1dc5b329637e872551fa6 = L.marker(
#                 [42.450633550000006, -82.96561635],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_214781746bcf3c32c6166253da6f639a = L.marker(
#                 [43.009302455882434, -83.77287272656855],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_087955fbafb2bf69cb80ed47ffe967e5 = L.marker(
#                 [42.91253261470188, -85.57186779081843],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_b1a95b38b90a8aeb235e75629c07f54c = L.marker(
#                 [42.88218598196104, -85.75789402891908],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_51597252e15617e15ce27286063efc50 = L.marker(
#                 [42.45018358345881, -82.9387287577088],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_cc7323ad3c3339060fd8ed94b04c5439 = L.marker(
#                 [42.407426243902435, -83.09823846341463],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_d71998163fc61a5459eb616293f87f27 = L.marker(
#                 [42.74124216370107, -84.9421082633452],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_58e2f8fbe52bd37ec5749e499bbe0d84 = L.marker(
#                 [43.150413, -86.20573],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_892e39f7be9e2fa28944c471e0162670 = L.marker(
#                 [42.49313805730977, -83.47601069842419],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_dca3c60f175d6e9143d592b5dadfbea9 = L.marker(
#                 [42.4494177, -83.20000127533112],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_431dc2c4b68bfee220d3795ca90b051d = L.marker(
#                 [42.725729, -84.4186215],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_c15cbe962935023979dffd94692f2314 = L.marker(
#                 [42.22021085, -85.5938936187197],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_e64b582cac7e2b94cb1f87a58e5dfa62);
#
#
#             var marker_7837ffdfc154094368cc4b9e81543064 = L.marker(
#                 [42.361231077038894, -83.27501438430247],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(ma

# %%
def get_geodata(address):
    try:
        return object.geocode(address)
    except:
        return None

object = geopy.Nominatim(user_agent = 'store_single')
location = '9189 Telegraph Rd Redford, MI 48239'
h1 = get_geodata(location)
if h1 is None:
    print('Correct your address')
else:
    map1=folium.Map(location= [h1.latitude, h1.longitude], zoom_start=10)
    folium.Marker([h1.latitude, h1.longitude], popup='store').add_to(map1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aac74b72c80b4386e82d10075f736ebe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aac74b72c80b4386e82d10075f736ebe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aac74b72c80b4386e82d10075f736ebe = L.map(
#                 &quot;map_aac74b72c80b4386e82d10075f736ebe&quot;,
#                 {
#                     center: [42.361231077038894, -83.27501438430247],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f462826a7653d82c1483abe4932c20f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f462826a7653d82c1483abe4932c20f.addTo(map_aac74b72c80b4386e82d10075f736ebe);
#
#
#             var marker_f0173b6bdca4aee70d5d4176b766649e = L.marker(
#                 [42.361231077038894, -83.27501438430247],
#                 {
# }
#             ).addTo(map_aac74b72c80b4386e82d10075f736ebe);
#
#
#         var popup_97b36a3739a454fd632663474007b6b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7e2cdbd75eb81edcf08e6e0ed1e00b0 = $(`&lt;div id=&quot;html_c7e2cdbd75eb81edcf08e6e0ed1e00b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;store&lt;/div&gt;`)[0];
#                 popup_97b36a3739a454fd632663474007b6b5.setContent(html_c7e2cdbd75eb81edcf08e6e0ed1e00b0);
#
#
#
#         marker_f0173b6bdca4aee70d5d4176b766649e.bindPopup(popup_97b36a3739a454fd632663474007b6b5)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import geopy
import folium
addr = ['672 Briarwood Circle Ann Arbor, MI 48108', '4186 Baldwin Rd Auburn Hills, MI 48326', '18900 Michigan Ave Dearborn, MI 48126',
        '1351 West 8 Mile Rd Detroit, MI 48203', '15015 East 8 Mile Rd Eastpointe, MI 48021', '3445 S Linden Rd, Flint, MI 48507',
        '3115 28th St SE, Kentwood, MI 49512', '3700 Rivertown Parkway Grandville, MI 49418', '17755 East 8 Mile Rd Harper Woods, MI 48225',
        '14108 Woodward Ave Highland Park, MI 48203', '5356 West Saginaw Highway Lansing, MI 48917', '5600 Harvey St Muskegon, MI 49444',
        '27694 Novi Rd Novi, MI 48377', '21230 Greenfield Rd Oak Park, MI 48237', '1982 W Grand River Ave Okemos, MI 48864',
        '6650 South Westnedge Ave Portage, MI 49024', '9189 Telegraph Rd, Redford, MI 48239', '32401 Gratiot Ave Roseville, MI 48066',
        '13825 Hall Rd Shelby Township, MI 48315', '28670 Telegraph Rd, Southfield, MI 48034', '23000 Eureka Rd, Taylor, MI 48180',
        '362 W 14 Mile Rd Troy, MI 48083', '35000 Warren Rd Westland, MI 48185']

object = geopy.Nominatim(user_agent = 'store_single')

def get_geodata(address):
    try:
        return object.geocode(address)
    except:
        return None
store_geodata = {}
incorrect_addr = []
cent_loc = 'Lansing, MI'
center = get_geodata(cent_loc)
if center is not None:
    map1 = folium.Map(location= [center.latitude, center.longitude], zoom_start=7)
    folium.Marker([center.latitude, center.longitude], popup='center store',
                  icon=folium.Icon(color="blue", icon="star")).add_to(map1)
else:
    print('The Map location is incorrect, cannot draw map')

for location in addr:
    geodata = get_geodata(location)
    if geodata is not None:
        folium.Marker([geodata.latitude, geodata.longitude], draggble=True,
                      icon=folium.Icon(color="red")).add_to(map1)
        store_geodata[location] = [geodata.latitude, geodata.longitude]
    else:
        incorrect_addr.append(location)
if len(incorrect_addr) != 0:
    print('These addresses are incorrect:', incorrect_addr)

print(store_geodata)

map1
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4186+Baldwin+Rd+Auburn+Hills%2C+MI+48326&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=4186+Baldwin+Rd+Auburn+Hills%2C+MI+48326&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=18900+Michigan+Ave+Dearborn%2C+MI+48126&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3445+S+Linden+Rd%2C+Flint%2C+MI+48507&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=3115+28th+St+SE%2C+Kentwood%2C+MI+49512&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=17755+East+8+Mile+Rd+Harper+Woods%2C+MI+48225&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=14108+Woodward+Ave+Highland+Park%2C+MI+48203&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=5600+Harvey+St+Muskegon%2C+MI+49444&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=27694+Novi+Rd+Novi%2C+MI+48377&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=9189+Telegraph+Rd%2C+Redford%2C+MI+48239&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=13825+Hall+Rd+Shelby+Township%2C+MI+48315&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=23000+Eureka+Rd%2C+Taylor%2C+MI+48180&format=json&limit=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)")': /search?q=35000+Warren+Rd+Westland%2C+MI+48185&format=json&limit=1
# {'672 Briarwood Circle Ann Arbor, MI 48108': [42.241050200000004, -83.74667569600683], '4186 Baldwin Rd Auburn Hills, MI 48326': [42.690368725344726, -83.30537551397458], '18900 Michigan Ave Dearborn, MI 48126': [42.31688655, -83.22296100140477], '1351 West 8 Mile Rd Detroit, MI 48203': [42.44519452516463, -83.18129761363781], '15015 East 8 Mile Rd Eastpointe, MI 48021': [42.450633550000006, -82.96561635], '3445 S Linden Rd, Flint, MI 48507': [43.009302455882434, -83.77287272656855], '3115 28th St SE, Kentwood, MI 49512': [42.912598406947, -85.58991399704016], '3700 Rivertown Parkway Grandville, MI 49418': [42.88218598196104, -85.75789402891908], '17755 East 8 Mile Rd Harper Woods, MI 48225': [42.45018358345881, -82.9387287577088], '14108 Woodward Ave Highland Park, MI 48203': [42.407426243902435, -83.09823846341463], '5356 West Saginaw Highway Lansing, MI 48917': [42.74124216370107, -84.9421082633452], '5600 Harvey St Muskegon, MI 49444': [43.150413, -86.20573], '27694 Novi Rd Novi, MI 48377': [42.49313805730977, -83.47601069842419], '21230 Greenfield Rd Oak Park, MI 48237': [42.4494177, -83.20000127533112], '1982 W Grand River Ave Okemos, MI 48864': [42.725729, -84.4186215], '6650 South Westnedge Ave Portage, MI 49024': [42.22021085, -85.5938936187197], '9189 Telegraph Rd, Redford, MI 48239': [42.361231077038894, -83.27501438430247], '32401 Gratiot Ave Roseville, MI 48066': [42.52314405345141, -82.91956298548446], '13825 Hall Rd Shelby Township, MI 48315': [42.62755612121212, -82.98930169696969], '28670 Telegraph Rd, Southfield, MI 48034': [42.4990255, -83.2845767], '23000 Eureka Rd, Taylor, MI 48180': [42.2002969, -83.25620864745882], '362 W 14 Mile Rd Troy, MI 48083': [42.534322332516396, -83.11046056888708], '35000 Warren Rd Westland, MI 48185': [42.3408406, -83.38944002231472]}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c9dc91bb90013764ab3aeb3a232e198 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c9dc91bb90013764ab3aeb3a232e198&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c9dc91bb90013764ab3aeb3a232e198 = L.map(
#                 &quot;map_2c9dc91bb90013764ab3aeb3a232e198&quot;,
#                 {
#                     center: [42.7338254, -84.5546295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f4c981a1bfe33c71d5225e45f08e7ea6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f4c981a1bfe33c71d5225e45f08e7ea6.addTo(map_2c9dc91bb90013764ab3aeb3a232e198);
#
#
#             var marker_be4db83439b878a191fc5934fc60f9a9 = L.marker(
#                 [42.7338254, -84.5546295],
#                 {
# }
#             ).addTo(map_2c9dc91bb90013764ab3aeb3a232e198);
#
#
#             var icon_6a5eeacf50a9218a510efe0485d99a20 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_be4db83439b878a191fc5934fc60f9a9.setIcon(icon_6a5eeacf50a9218a510efe0485d99a20);
#
#
#         var popup_5b5c6303099c215f395ba50882061938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83525cdfc41f0f8501901a3cbc5ecf43 = $(`&lt;div id=&quot;html_83525cdfc41f0f8501901a3cbc5ecf43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;center store&lt;/div&gt;`)[0];
#                 popup_5b5c6303099c215f395ba50882061938.setContent(html_83525cdfc41f0f8501901a3cbc5ecf43);
#
#
#
#         marker_be4db83439b878a191fc5934fc60f9a9.bindPopup(popup_5b5c6303099c215f395ba50882061938)
#         ;
#
#
#
#
#             var marker_71834a3bf3f7c7321854e062fb2c84c0 = L.marker(
#                 [42.241050200000004, -83.74667569600683],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_2c9dc91bb90013764ab3aeb3a232e198);
#
#
#             var icon_9d29ee5a4d89f1c29c208307ba1e8d61 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_71834a3bf3f7c7321854e062fb2c84c0.setIcon(icon_9d29ee5a4d89f1c29c208307ba1e8d61);
#
#
#             var marker_dbb2c38b8582650f59a687eb71175041 = L.marker(
#                 [42.690368725344726, -83.30537551397458],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_2c9dc91bb90013764ab3aeb3a232e198);
#
#
#             var icon_8a3b38a3de7a2015256ee8d4d86d17eb = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_dbb2c38b8582650f59a687eb71175041.setIcon(icon_8a3b38a3de7a2015256ee8d4d86d17eb);
#
#
#             var marker_7d068364fb31e0d0c3dac6b43919727a = L.marker(
#                 [42.31688655, -83.22296100140477],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_2c9dc91bb90013764ab3aeb3a232e198);
#
#
#             var icon_f3915613e4180126cebf18a99d19acfc = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_7d068364fb31e0d0c3dac6b43919727a.setIcon(icon_f3915613e4180126cebf18a99d19acfc);
#
#
#             var marker_52e9df168cc6a18fbb234a06eb1d6608 = L.marker(
#                 [42.44519452516463, -83.18129761363781],
#                 {
#   &quot;draggble&quot;: true,
# }
#             ).addTo(map_2c9dc91bb90013764ab3aeb3a232e198);
#
#
#             var icon_4f4096a9349ce1bbc3cad68d56bada66 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#             marker_52e9df168cc6a18fbb234a06eb1d6608.setIcon(icon_4f4096a9349ce1bbc3cad68d56bada66);
#
#
#             var marker_dd86b8019c0f9fb5d6c

# %%
store_geodata.values()
# Out:
# dict_values([[42.241050200000004, -83.74667569600683], [42.690368725344726, -83.30537551397458], [42.31688655, -83.22296100140477], [42.44519452516463, -83.18129761363781], [42.450633550000006, -82.96561635], [43.009302455882434, -83.77287272656855], [42.912598406947, -85.58991399704016], [42.88218598196104, -85.75789402891908], [42.45018358345881, -82.9387287577088], [42.407426243902435, -83.09823846341463], [42.74124216370107, -84.9421082633452], [43.150413, -86.20573], [42.49313805730977, -83.47601069842419], [42.4494177, -83.20000127533112], [42.725729, -84.4186215], [42.22021085, -85.5938936187197], [42.361231077038894, -83.27501438430247], [42.52314405345141, -82.91956298548446], [42.62755612121212, -82.98930169696969], [42.4990255, -83.2845767], [42.2002969, -83.25620864745882], [42.534322332516396, -83.11046056888708], [42.3408406, -83.38944002231472]])

# %%
from sklearn import cluster
CLUSTERS = 4
k_means = cluster.KMeans(n_clusters=CLUSTERS, random_state = 12)
X = store_geodata.values()
k_means.fit(X)
print(k_means.cluster_centers_)
for plt in k_means.cluster_centers_:
    folium.Circle(location = plt, fill_color='red', radius = 20000, weight= 2, color='black').add_to(map1)
#map1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-49382a6592a6> in <cell line: 0>()
#       3 k_means = cluster.KMeans(n_clusters=CLUSTERS, random_state = 12)
#       4 X = store_geodata.values()
# ----> 5 k_means.fit(X)
#       6 print(k_means.cluster_centers_)
#       7 for plt in k_means.cluster_centers_:
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1452             Fitted estimator.
#    1453         """
# -> 1454         X = validate_data(
#    1455             self,
#    1456             X,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
# -> 1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp, device)
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#
# TypeError: float() argument must be a string or a real number, not 'dict_values'

# %%
#Python


import pandas as pd
from sklearn.cluster import KMeans

# Create a DataFrame with a dictionary-like structure
data = {'feature1': [1, 2, 3], 'feature2': [4, 5, 6]}
df = pd.DataFrame(data)

# Extract numerical values into a NumPy array
X = df.values
print(X)
# Fit KMeans
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# [[1 4]
#  [2 5]
#  [3 6]]
# KMeans(n_clusters=2)

# %%
#color icons
nyc_INJURED = folium.Map(location=[40.730610, -73.935242], tiles='Stamen Terrain', zoom_start=10)
folium.Marker([max_PEDESTRIANS_INJURED['LATITUDE'], max_PEDESTRIANS_INJURED['LONGITUDE']],
             icon=folium.Icon(color="red", icon="info-sign"),).add_to(nyc_INJURED)
folium.Marker([max_CYCLISTS_INJURED['LATITUDE'][82102], max_CYCLISTS_INJURED['LONGITUDE'][82102]],
             icon=folium.Icon(color="green", icon="flag"),).add_to(nyc_INJURED)
folium.Marker([max_CYCLISTS_INJURED['LATITUDE'][145777], max_CYCLISTS_INJURED['LONGITUDE'][145777]],
             icon=folium.Icon(color="green", icon="flag"),).add_to(nyc_INJURED)
folium.Marker([max_MOTORISTS_INJURED['LATITUDE'], max_MOTORISTS_INJURED['LONGITUDE']],
             icon=folium.Icon(color="blue", icon="star"),).add_to(nyc_INJURED)
nyc_INJURED


nyc_INJURED = folium.Map(location=[40.730610, -73.935242], tiles='Stamen Terrain', zoom_start=10)
folium.Marker([max_PEDESTRIANS_INJURED['LATITUDE'], max_PEDESTRIANS_INJURED['LONGITUDE']],
             icon=folium.Icon(color='red', prefix='fa',icon='male')).add_to(nyc_INJURED)
folium.Marker([max_CYCLISTS_INJURED['LATITUDE'][82102], max_CYCLISTS_INJURED['LONGITUDE'][82102]],
             icon=folium.Icon(color='green', prefix='fa',icon='bicycle')).add_to(nyc_INJURED)
folium.Marker([max_CYCLISTS_INJURED['LATITUDE'][145777], max_CYCLISTS_INJURED['LONGITUDE'][145777]],
             icon=folium.Icon(color='green', prefix='fa',icon='bicycle')).add_to(nyc_INJURED)
folium.Marker([max_MOTORISTS_INJURED['LATITUDE'], max_MOTORISTS_INJURED['LONGITUDE']],
             icon=folium.Icon(color='blue',prefix='fa',icon='car')).add_to(nyc_INJURED)
nyc_INJURED

let’s add folium.LatLngPopup() so we can get latitude/longitude information by clicking anywhere on the map.

MORE INFO
https://darigak.medium.com/your-guide-to-folium-markers-b9324fc7d65d

# %%
print(k_means.cluster_centers_[1])
# Out:
# [ 42.4370998  -83.12131246]

# %%
from geopy.distance import geodesic
cust_address = '36385 Grand River Ave, MI 48335'
store_address = '672 Briarwood Circle Ann Arbor, MI 48108'
s = get_geodata(cust_address)
d = get_geodata(store_address)
source = (s.latitude, s.longitude)
destination = (d.latitude, d.longitude)
print(geodesic(source, destination).miles)
# Out:
# (42.468882192307696, -83.40762634965034) (42.241050200000004, -83.74667569600683)
# 23.421411000643374

# %%
from geopy.distance import geodesic
def min_distance(source, destination):
        try:
            return (geodesic(source, destination).miles)
        except:
            return None

# %%
cust_address = '36385 Grand River Ave, MI 48335'
s = get_geodata(cust_address)
source = [s.latitude, s.longitude]
min_dist = {}
for key, val in store_geodata.items():
    dist = min_distance(source, val)
    min_dist[dist] = key

nearest = min(min_dist.keys())
print(nearest, min_dist[nearest])
# Out:
# 3.874287739146542 27694 Novi Rd Novi, MI 48377

# %%
pip install geopy
# Out:
# Collecting geopyNote: you may need to restart the kernel to use updated packages.
#   Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
table
# Out:
# ['\n672 Briarwood Circle \nAnn Arbor, MI 48108\n']

# %%
# Out:
# ['672 Briarwood Circle Ann Arbor, MI 48108']

# %%
from bs4 import BeautifulSoup
import requests

url = "https://stores.footlocker.com/mi/"
# get html content from url
html_content = requests.get(url).text
# parse the content
soup = BeautifulSoup(html_content, 'lxml')
#print(soup.prettify()) #print the parsed data
#soup.prettify()
table = soup.find_all('li', attrs = {'class' : 'map-list-item-wrap is-single'})
print(table)
for row in table.find_all('div', attrs = {'class' : 'data-city-item'}):
    print(row)
# Out:
# [<li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Ann Arbor" data-ga="Maplist, City - Ann Arbor" data-search-term="Ann Arbor, Michigan" href="https://stores.footlocker.com/mi/annarbor/" title="Stores in Ann Arbor">
#             Ann Arbor<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Auburn Hills" data-ga="Maplist, City - Auburn Hills" data-search-term="Auburn Hills, Michigan" href="https://stores.footlocker.com/mi/auburnhills/" title="Stores in Auburn Hills">
#             Auburn Hills<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Dearborn" data-ga="Maplist, City - Dearborn" data-search-term="Dearborn, Michigan" href="https://stores.footlocker.com/mi/dearborn/" title="Stores in Dearborn">
#             Dearborn<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Detroit" data-ga="Maplist, City - Detroit" data-search-term="Detroit, Michigan" href="https://stores.footlocker.com/mi/detroit/" title="Stores in Detroit">
#             Detroit<span class="location-count">(9)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Eastpointe" data-ga="Maplist, City - Eastpointe" data-search-term="Eastpointe, Michigan" href="https://stores.footlocker.com/mi/eastpointe/" title="Stores in Eastpointe">
#             Eastpointe<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Flint" data-ga="Maplist, City - Flint" data-search-term="Flint, Michigan" href="https://stores.footlocker.com/mi/flint/" title="Stores in Flint">
#             Flint<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Grand Rapids" data-ga="Maplist, City - Grand Rapids" data-search-term="Grand Rapids, Michigan" href="https://stores.footlocker.com/mi/grandrapids/" title="Stores in Grand Rapids">
#             Grand Rapids<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Grandville" data-ga="Maplist, City - Grandville" data-search-term="Grandville, Michigan" href="https://stores.footlocker.com/mi/grandville/" title="Stores in Grandville">
#             Grandville<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Harper Woods" data-ga="Maplist, City - Harper Woods" data-search-term="Harper Woods, Michigan" href="https://stores.footlocker.com/mi/harperwoods/" title="Stores in Harper Woods">
#             Harper Woods<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Highland Park" data-ga="Maplist, City - Highland Park" data-search-term="Highland Park, Michigan" href="https://stores.footlocker.com/mi/highlandpark/" title="Stores in Highland Park">
#             Highland Park<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Lansing" data-ga="Maplist, City - Lansing" data-search-term="Lansing, Michigan" href="https://stores.footlocker.com/mi/lansing/" title="Stores in Lansing">
#             Lansing<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Muskegon" data-ga="Maplist, City - Muskegon" data-search-term="Muskegon, Michigan" href="https://stores.footlocker.com/mi/muskegon/" title="Stores in Muskegon">
#             Muskegon<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Novi" data-ga="Maplist, City - Novi" data-search-term="Novi, Michigan" href="https://stores.footlocker.com/mi/novi/" title="Stores in Novi">
#             Novi<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Oak Park" data-ga="Maplist, City - Oak Park" data-search-term="Oak Park, Michigan" href="https://stores.footlocker.com/mi/oakpark/" title="Stores in Oak Park">
#             Oak Park<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Okemos" data-ga="Maplist, City - Okemos" data-search-term="Okemos, Michigan" href="https://stores.footlocker.com/mi/okemos/" title="Stores in Okemos">
#             Okemos<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Portage" data-ga="Maplist, City - Portage" data-search-term="Portage, Michigan" href="https://stores.footlocker.com/mi/portage/" title="Stores in Portage">
#             Portage<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Redford" data-ga="Maplist, City - Redford" data-search-term="Redford, Michigan" href="https://stores.footlocker.com/mi/redford/" title="Stores in Redford">
#             Redford<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Roseville" data-ga="Maplist, City - Roseville" data-search-term="Roseville, Michigan" href="https://stores.footlocker.com/mi/roseville/" title="Stores in Roseville">
#             Roseville<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Shelby Township" data-ga="Maplist, City - Shelby Township" data-search-term="Shelby Township, Michigan" href="https://stores.footlocker.com/mi/shelbytownship/" title="Stores in Shelby Township">
#             Shelby Township<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Southfield" data-ga="Maplist, City - Southfield" data-search-term="Southfield, Michigan" href="https://stores.footlocker.com/mi/southfield/" title="Stores in Southfield">
#             Southfield<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Taylor" data-ga="Maplist, City - Taylor" data-search-term="Taylor, Michigan" href="https://stores.footlocker.com/mi/taylor/" title="Stores in Taylor">
#             Taylor<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Troy" data-ga="Maplist, City - Troy" data-search-term="Troy, Michigan" href="https://stores.footlocker.com/mi/troy/" title="Stores in Troy">
#             Troy<span class="location-count">(2)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Westland" data-ga="Maplist, City - Westland" data-search-term="Westland, Michigan" href="https://stores.footlocker.com/mi/westland/" title="Stores in Westland">
#             Westland<span class="location-count">(1)</span>
# </a>
# </div>
# </li>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-4a205b69712b> in <module>
#      11 table = soup.find_all('li', attrs = {'class' : 'map-list-item-wrap is-single'})
#      12 print(table)
# ---> 13 for row in table.find_all('div', attrs = {'class' : 'data-city-item'}):
#      14     print(row)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
table = soup.find_all('li', attrs = {'class' : 'map-list-item-wrap is-single'})
print(table)
for row in table.find_all('div', attrs = {'class' : 'data-city-item'}):
    print(row)
# Out:
# [<li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Ann Arbor" data-ga="Maplist, City - Ann Arbor" data-search-term="Ann Arbor, Michigan" href="https://stores.footlocker.com/mi/annarbor/" title="Stores in Ann Arbor">
#             Ann Arbor<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Auburn Hills" data-ga="Maplist, City - Auburn Hills" data-search-term="Auburn Hills, Michigan" href="https://stores.footlocker.com/mi/auburnhills/" title="Stores in Auburn Hills">
#             Auburn Hills<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Dearborn" data-ga="Maplist, City - Dearborn" data-search-term="Dearborn, Michigan" href="https://stores.footlocker.com/mi/dearborn/" title="Stores in Dearborn">
#             Dearborn<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Detroit" data-ga="Maplist, City - Detroit" data-search-term="Detroit, Michigan" href="https://stores.footlocker.com/mi/detroit/" title="Stores in Detroit">
#             Detroit<span class="location-count">(9)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Eastpointe" data-ga="Maplist, City - Eastpointe" data-search-term="Eastpointe, Michigan" href="https://stores.footlocker.com/mi/eastpointe/" title="Stores in Eastpointe">
#             Eastpointe<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Flint" data-ga="Maplist, City - Flint" data-search-term="Flint, Michigan" href="https://stores.footlocker.com/mi/flint/" title="Stores in Flint">
#             Flint<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Grand Rapids" data-ga="Maplist, City - Grand Rapids" data-search-term="Grand Rapids, Michigan" href="https://stores.footlocker.com/mi/grandrapids/" title="Stores in Grand Rapids">
#             Grand Rapids<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Grandville" data-ga="Maplist, City - Grandville" data-search-term="Grandville, Michigan" href="https://stores.footlocker.com/mi/grandville/" title="Stores in Grandville">
#             Grandville<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Harper Woods" data-ga="Maplist, City - Harper Woods" data-search-term="Harper Woods, Michigan" href="https://stores.footlocker.com/mi/harperwoods/" title="Stores in Harper Woods">
#             Harper Woods<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Highland Park" data-ga="Maplist, City - Highland Park" data-search-term="Highland Park, Michigan" href="https://stores.footlocker.com/mi/highlandpark/" title="Stores in Highland Park">
#             Highland Park<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Lansing" data-ga="Maplist, City - Lansing" data-search-term="Lansing, Michigan" href="https://stores.footlocker.com/mi/lansing/" title="Stores in Lansing">
#             Lansing<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Muskegon" data-ga="Maplist, City - Muskegon" data-search-term="Muskegon, Michigan" href="https://stores.footlocker.com/mi/muskegon/" title="Stores in Muskegon">
#             Muskegon<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Novi" data-ga="Maplist, City - Novi" data-search-term="Novi, Michigan" href="https://stores.footlocker.com/mi/novi/" title="Stores in Novi">
#             Novi<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Oak Park" data-ga="Maplist, City - Oak Park" data-search-term="Oak Park, Michigan" href="https://stores.footlocker.com/mi/oakpark/" title="Stores in Oak Park">
#             Oak Park<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Okemos" data-ga="Maplist, City - Okemos" data-search-term="Okemos, Michigan" href="https://stores.footlocker.com/mi/okemos/" title="Stores in Okemos">
#             Okemos<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Portage" data-ga="Maplist, City - Portage" data-search-term="Portage, Michigan" href="https://stores.footlocker.com/mi/portage/" title="Stores in Portage">
#             Portage<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Redford" data-ga="Maplist, City - Redford" data-search-term="Redford, Michigan" href="https://stores.footlocker.com/mi/redford/" title="Stores in Redford">
#             Redford<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Roseville" data-ga="Maplist, City - Roseville" data-search-term="Roseville, Michigan" href="https://stores.footlocker.com/mi/roseville/" title="Stores in Roseville">
#             Roseville<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Shelby Township" data-ga="Maplist, City - Shelby Township" data-search-term="Shelby Township, Michigan" href="https://stores.footlocker.com/mi/shelbytownship/" title="Stores in Shelby Township">
#             Shelby Township<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Southfield" data-ga="Maplist, City - Southfield" data-search-term="Southfield, Michigan" href="https://stores.footlocker.com/mi/southfield/" title="Stores in Southfield">
#             Southfield<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Taylor" data-ga="Maplist, City - Taylor" data-search-term="Taylor, Michigan" href="https://stores.footlocker.com/mi/taylor/" title="Stores in Taylor">
#             Taylor<span class="location-count">(1)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Troy" data-ga="Maplist, City - Troy" data-search-term="Troy, Michigan" href="https://stores.footlocker.com/mi/troy/" title="Stores in Troy">
#             Troy<span class="location-count">(2)</span>
# </a>
# </div>
# </li>, <li class="map-list-item-wrap is-single">
# <div class="map-list-item is-single">
# <a class="ga-link" data-city-item="Westland" data-ga="Maplist, City - Westland" data-search-term="Westland, Michigan" href="https://stores.footlocker.com/mi/westland/" title="Stores in Westland">
#             Westland<span class="location-count">(1)</span>
# </a>
# </div>
# </li>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-342f95255376> in <module>
#       1 table = soup.find_all('li', attrs = {'class' : 'map-list-item-wrap is-single'})
#       2 print(table)
# ----> 3 for row in table.find_all('div', attrs = {'class' : 'data-city-item'}):
#       4     print(row)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for row in table.findAll('div', attrs = {'class' : 'data-city-item'}):
    print(row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-956f94f49112> in <module>
# ----> 1 for row in table.findAll('div', attrs = {'class' : 'data-city-item'}):
#       2     print(row)
#
# ~\anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    2171     def __getattr__(self, key):
#    2172         """Raise a helpful exception to explain a common code fix."""
# -> 2173         raise AttributeError(
#    2174             "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175         )
#
# AttributeError: ResultSet object has no attribute 'findAll'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
for row in table_content.find_all('div', attrs = {'class':'map-list-item is-single'}):
    print(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f0facbc39200> in <module>
# ----> 1 for row in table_content.find_all('div', attrs = {'class':'map-list-item is-single'}):
#       2     print(row)
#
# NameError: name 'table_content' is not defined
